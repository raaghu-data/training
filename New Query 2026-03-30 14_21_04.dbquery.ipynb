-- %%
-- CREATE SCHEMA practice1.bronze;
-- CREATE SCHEMA practice1.silver;
-- CREATE SCHEMA practice1.gold;

CREATE TABLE practice1.test.emp_window (
    emp_id INT,
    name STRING,
    department STRING,
    salary INT
)


INSERT INTO employee VALUES
(1, 'A', 'IT', 5000),
(2, 'B', 'IT', 6000),
(3, 'C', 'IT', 6000),
(4, 'D', 'HR', 4000),
(5, 'E', 'HR', 4000),
(6, 'F', 'HR', 3000);
